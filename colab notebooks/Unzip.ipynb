# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Developer/ShapeNetCore_pointclouds
# !unzip ShapeNetCore.v2.PC15k.zip

# %%
# !du -sh /content/ShapeNetCore.v2.PC15k
# Out:
# 8.6G	/content/ShapeNetCore.v2.PC15k

# %%
# !rmdir __MACOSX/
