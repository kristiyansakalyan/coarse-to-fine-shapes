# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=False)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes
# Out:
# /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes

# %%
# !git status
# Out:
# ^C

# %%
# !git add /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/eval-results/point-transformer/2024-02-02_19-09-12_global_refinment
# !git commit -m "Add second pt global refinment eval results (no residuals)"
# !git push

# %%
# %cd /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/eval-results/point-transformer/2024-01-30_23-46-44
# Out:
# /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/eval-results/point-transformer/2024-01-30_23-46-44

# %%
# !git commit -m "Add eval input output for point-transformer"
# Out:
# [main 3e4ec87] Add eval input output for point-transformer
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 eval-results/point-transformer/2024-01-30_23-46-44/input_pcs.pt
#  create mode 100644 eval-results/point-transformer/2024-01-30_23-46-44/output_pcs.pt

# %%
# !git config pull.ff only

# %%
# !git commit -m "merge main"
# Out:
# [main c28746c] merge main

# %%
# !git pull
# Out:
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %%
# !git push
# Out:
# Enumerating objects: 13, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (9/9), 16.36 MiB | 524.00 KiB/s, done.
# Total 9 (delta 3), reused 0 (delta 0), pack-reused 0
# To https://gitlab.lrz.de/00000000014A00FC/coarse-to-fine-shapes.git
#    3830673..c28746c  main -> main
