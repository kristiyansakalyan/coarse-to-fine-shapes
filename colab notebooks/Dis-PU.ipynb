# %% [markdown]
# # Point Cloud Upsampling via Disentangled Reﬁnement
# https://github.com/liruihui/Dis-PU.git

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=False)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Developer
# Out:
# /content/gdrive/MyDrive/Developer

# %%
# !git clone https://github.com/liruihui/Dis-PU.git
# Out:
# Cloning into 'Dis-PU'...
# remote: Enumerating objects: 380, done.
# remote: Counting objects: 100% (380/380), done.
# remote: Compressing objects: 100% (250/250), done.
# remote: Total 380 (delta 122), reused 366 (delta 116), pack-reused 0
# Receiving objects: 100% (380/380), 14.03 MiB | 3.31 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
# Updating files: 100% (338/338), done.

# %%
# %cd Dis-PU
# Out:
# /content/gdrive/MyDrive/Developer/Dis-PU

# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# !python3 -m pip install tensorflow[and-cuda]

# %%
# !sh complile_op.sh
# Out:
# sh: 0: cannot open complile_op.sh: No such file
