# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=False)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Developer
# Out:
# /content/gdrive/MyDrive/Developer

# %%
# !pip install mitsuba
# Out:
# Collecting mitsuba
#   Downloading mitsuba-3.5.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (40.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 MB 23.2 MB/s eta 0:00:00
# Collecting drjit==0.4.4 (from mitsuba)
#   Downloading drjit-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 77.4 MB/s eta 0:00:00
# Installing collected packages: drjit, mitsuba
# Successfully installed drjit-0.4.4 mitsuba-3.5.0

# %%
# %cd /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes
# !git pull
# Out:
# /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), 1009.40 KiB | 1.18 MiB/s, done.
# From https://gitlab.lrz.de/00000000014A00FC/coarse-to-fine-shapes
#    8c9a454..ad138a4  main       -> origin/main
# Updating 0f23b2a..ad138a4
# Fast-forward
#  models_adl4cv/loss.py                                           |  22 ++++
#  poin_transformer_vis.ipynb                                      | 193 ++++++++++++++++++++++++++++
#  ..._Part_Patch_Refinement-Class-Condition-Chair-Residuals.ipynb |  52 ++++++++
#  visuals/mitsuba_vis.py                                          |  44 ++++++-
#  4 files changed, 305 insertions(+), 6 deletions(-)
#  create mode 100644 models_adl4cv/loss.py
#  create mode 100644 poin_transformer_vis.ipynb

# %%
# !python3 visuals/mitsuba_vis.py --input /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/00-input.pth --ouput /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/00-input-r0_015.pth --radius 0.015
# Out:
# usage: mitsuba_vis.py [-h] [--input INPUT] [--output OUTPUT] [--fov FOV] [--clr CLR CLR CLR]
#                       [--radius RADIUS]
# mitsuba_vis.py: error: unrecognized arguments: --ouput /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/00-input-r0_015.pth

# %%
from visuals.mitsuba_vis import render_mitsuba
import matplotlib.pyplot as plt

# %%
# %cd /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44
# Out:
# /content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44

# %%
point_cloud = point_cloud.numpy().squeeze()

# %%
point_cloud.shape
# Out:
# (2048, 3)

# %%
base_dir = "/content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44"

# %%
data = {i: {typ: torch.load(f"{base_dir}/{i:02d}-{typ}.pth", map_location=torch.device('cpu')).numpy().squeeze() for typ in ("input", "refined_output")} for i in range(10)}

# %%
print(data)
# Out:
# {0: {'input': array([[ 0.03230878,  0.46594542,  1.9528685 ],
#        [-0.18875988,  0.7303847 , -0.6912581 ],
#        [ 1.0841774 , -0.6011624 , -0.506949  ],
#        ...,
#        [-1.4363827 , -0.53714865, -0.45227104],
#        [ 0.1539816 ,  0.01095959, -0.37900883],
#        [ 2.862818  ,  0.2512831 , -0.43941265]], dtype=float32), 'refined_output': array([[ 0.02290793,  0.44315696,  1.9465525 ],
#        [-0.16882634,  0.73378485, -0.690039  ],
#        [ 1.0912256 , -0.6086119 , -0.48199964],
#        ...,
#        [-1.3684396 , -0.4830661 , -0.43968037],
#        [ 0.16446137,  0.01651704, -0.37157878],
#        [ 2.8477309 ,  0.23449726, -0.43655577]], dtype=float32)}, 1: {'input': array([[ 0.20650604, -0.07057355, -3.1212728 ],
#        [ 0.22589774, -0.12907316, -0.7114108 ],
#        [-0.1391534 ,  0.21603768, -2.6937695 ],
#        ...,
#        [ 0.29951614, -0.06605487, -0.8788036 ],
#        [ 0.25414288, -0.06260214, -1.2000068 ],
#        [-0.21997695, -0.24788004, -1.239255  ]], dtype=float32), 'refined_output': array([[ 0.21025963, -0.06700381, -3.115911  ],
#        [ 0.2168709 , -0.13745257, -0.71099955],
#        [-0.13804097,  0.20442575, -2.6979337 ],
#        ...,
#        [ 0.27244642, -0.08452277, -0.88111484],
#        [ 0.24899605, -0.08701731, -1.1965662 ],
#        [-0.19177765, -0.2048729 , -1.238865  ]], dtype=float32)}, 2: {'input': array([[ 0.17121263, -0.14017802,  0.9940624 ],
#        [-0.9207711 ,  0.03281501,  0.19783343],
#        [-0.04894599, -0.18992972, -0.4217257 ],
#        ...,
#        [-0.32702133,  0.04473233,  0.7544884 ],
#        [ 0.57503265, -0.04304438, -0.11551359],
#        [-0.30742648, -0.09538336,  0.37729305]], dtype=float32), 'refined_output': array([[ 0.13785836, -0.1385072 ,  0.99350286],
#        [-0.9104715 ,  0.01524651,  0.17376079],
#        [-0.03825299, -0.14227454, -0.42245758],
#        ...,
#        [-0.3048898 ,  0.0267795 ,  0.75447875],
#        [ 0.57829386, -0.02973771, -0.12684883],
#        [-0.24477546, -0.05828379,  0.3739929 ]], dtype=float32)}, 3: {'input': array([[ 1.3133106 ,  0.04993088, -0.09788476],
#        [-0.77164   ,  0.00495411, -0.17688924],
#        [ 0.72418886, -0.00340411, -0.8222059 ],
#        ...,
#        [ 0.07892545, -0.24308735,  0.18245745],
#        [ 0.7226413 , -0.01819864, -0.17472664],
#        [ 0.47589475,  0.02601335, -0.5823823 ]], dtype=float32), 'refined_output': array([[ 1.3078698e+00,  2.9001873e-02, -9.2819899e-02],
#        [-7.6945549e-01, -1.9677924e-03, -1.9105320e-01],
#        [ 7.2379136e-01, -4.2110026e-02, -8.2044744e-01],
#        ...,
#        [ 6.2961273e-02, -2.3912293e-01,  1.8358976e-01],
#        [ 7.1157062e-01,  3.2693893e-04, -1.9384229e-01],
#        [ 4.8781201e-01,  4.0457901e-03, -5.8447570e-01]], dtype=float32)}, 4: {'input': array([[-2.0670075 , -0.30743214, -0.6953168 ],
#        [ 0.6819869 ,  0.13304354,  1.9937835 ],
#        [-0.25735894,  0.13079038,  1.0176965 ],
#        ...,
#        [-1.6979387 , -0.26376846, -0.8518134 ],
#        [ 0.12929311,  0.45290282, -0.6723667 ],
#        [ 0.64646477,  0.14225799,  2.264096  ]], dtype=float32), 'refined_output': array([[-2.0519195 , -0.2712227 , -0.69610095],
#        [ 0.69255954,  0.10993895,  2.0113375 ],
#        [-0.24370296,  0.12542666,  1.0192161 ],
#        ...,
#        [-1.7164645 , -0.27524924, -0.81820273],
#        [ 0.1508137 ,  0.47446305, -0.6709548 ],
#        [ 0.6543129 ,  0.1165933 ,  2.2375827 ]], dtype=float32)}, 5: {'input': array([[ 1.8989859 , -0.00563302, -0.2602214 ],
#        [ 0.09043872, -0.3129166 , -1.8657362 ],
#        [ 3.2911093 ,  0.06864467, -0.27386954],
#        ...,
#        [-1.127069  , -0.01222153, -0.63331336],
#        [-0.660694  , -0.13078104, -0.5012442 ],
#        [-0.8812632 , -0.0482296 , -0.19262378]], dtype=float32), 'refined_output': array([[ 1.8941188 ,  0.03352998, -0.266003  ],
#        [ 0.08785612, -0.2553636 , -1.8661069 ],
#        [ 3.292773  ,  0.08273349, -0.28234026],
#        ...,
#        [-1.1198536 , -0.00633395, -0.6269243 ],
#        [-0.6565328 , -0.07657154, -0.5041205 ],
#        [-0.8729632 , -0.0479332 , -0.20221558]], dtype=float32)}, 6: {'input': array([[-0.16962005,  0.36942956,  2.2289262 ],
#        [ 1.0025228 , -0.31073722, -0.81724787],
#        [ 0.57481176,  0.08800606, -0.05872072],
#        ...,
#        [-0.24935097,  0.5393317 ,  1.1300912 ],
#        [-0.23852319,  0.02418253, -2.2512796 ],
#        [ 1.1967493 ,  0.07282374, -0.29719973]], dtype=float32), 'refined_output': array([[-0.14823377,  0.36823523,  2.2282677 ],
#        [ 0.9745924 , -0.25081056, -0.8143191 ],
#        [ 0.5740668 ,  0.04264329, -0.06968135],
#        ...,
#        [-0.25114033,  0.53002787,  1.1429    ],
#        [-0.22747639,  0.01646814, -2.2533293 ],
#        [ 1.1831355 ,  0.09982473, -0.28910667]], dtype=float32)}, 7: {'input': array([[-0.27810556, -0.19830534,  0.25717402],
#        [ 0.00746397,  0.48101476,  2.579955  ],
#        [-1.9085263 ,  0.04981151,  0.8162057 ],
#        ...,
#        [-0.01251301,  1.2193879 ,  2.501633  ],
#        [-2.3181183 ,  0.09593089,  0.8893828 ],
#        [ 0.0237977 , -0.28024465, -2.3111818 ]], dtype=float32), 'refined_output': array([[-0.27941707, -0.1954178 ,  0.25261605],
#        [-0.03365326,  0.47542286,  2.5708926 ],
#        [-1.9355086 ,  0.05939634,  0.7876892 ],
#        ...,
#        [-0.00938463,  1.1976589 ,  2.5028157 ],
#        [-2.3325326 ,  0.08474024,  0.8597527 ],
#        [ 0.02691033, -0.25874412, -2.3203561 ]], dtype=float32)}, 8: {'input': array([[-0.18490008, -0.18428002, -2.0127118 ],
#        [ 0.07468829, -0.32920542,  0.3495116 ],
#        [-0.1964206 , -0.12537289, -0.46772245],
#        ...,
#        [-0.07801528, -0.21517806, -2.606121  ],
#        [ 0.00729549,  0.12977888,  2.3508606 ],
#        [ 0.83301294, -0.17441231,  0.06584443]], dtype=float32), 'refined_output': array([[-0.17497279, -0.1598004 , -2.0159075 ],
#        [ 0.06189495, -0.30753213,  0.35272223],
#        [-0.22999105, -0.144512  , -0.46938044],
#        ...,
#        [-0.05113392, -0.19523561, -2.5991805 ],
#        [-0.01669639,  0.07726063,  2.3222532 ],
#        [ 0.8292536 , -0.18798809,  0.04033911]], dtype=float32)}, 9: {'input': array([[-0.24460012, -0.18777649, -3.0593402 ],
#        [ 0.05427422,  0.14125858,  1.4777831 ],
#        [-0.35677296, -0.18759684, -2.0916712 ],
#        ...,
#        [-0.03497632,  0.3665191 , -3.1656294 ],
#        [ 0.14841652,  0.4079313 , -2.2989812 ],
#        [-1.1913172 ,  0.15364361, -1.2430563 ]], dtype=float32), 'refined_output': array([[-0.21114425, -0.18597592, -3.0645664 ],
#        [ 0.03047584,  0.1363462 ,  1.4744488 ],
#        [-0.3694242 , -0.18943477, -2.0949857 ],
#        ...,
#        [-0.04055877,  0.37042075, -3.1555977 ],
#        [ 0.14677843,  0.37346852, -2.3040264 ],
#        [-1.1699928 ,  0.07634737, -1.2275463 ]], dtype=float32)}}

# %%
for index, results in data.items():
  for typ, point_cloud in results.items():
    plot_name = f"./pt-{index}-{typ}"
    img = render_mitsuba(point_cloud, f"{plot_name}.xml", fov=20)
    plt.axis("off")
    plt.imshow(img ** (1.0 / 2.2)); # approximate sRGB tonemapping
    plt.savefig(f"{plot_name}.png", bbox_inches='tight', pad_inches=0, dpi=400)
# Out:
# Center: [-0.0119189   0.19930294  0.7886159 ], Scale: 6.138422012329102
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Center: [-0.01906192  0.19360769  0.7784953 ], Scale: 6.048279762268066
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Center: [ 0.04153574  0.33070058 -0.46492612], Scale: 5.887690544128418
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Center: [ 0.03139925  0.32173926 -0.4745729 ], Scale: 5.78542947769165
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Center: [ 0.06918955  0.4753191  -0.20121503], Scale: 5.772909641265869
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Center: [ 0.09091902  0.47721797 -0.21012223], Scale: 5.676958084106445

# %%
for i in range(10):
  img = render_mitsuba(point_cloud, "./test.xml", fov=20)

# %%
plt.axis("off")
plt.imshow(img ** (1.0 / 2.2)); # approximate sRGB tonemapping
plt.savefig("test.png", bbox_inches='tight', pad_inches=0, dpi=400)

# %%
plt.savefig(f"test.png", dpi=400)

# %%
from google.colab import files
base_path = "/content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44"
zip_name = f"{base_path}.zip"
# !zip -r {zip_name} {str(base_path)}
files.download(zip_name)
# Out:
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/ (stored 0%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/00-input.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/00-residuals.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/00-refined_output.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/01-input.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/01-residuals.pth (deflated 35%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/01-refined_output.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/02-input.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/02-residuals.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/02-refined_output.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/03-input.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/03-residuals.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/03-refined_output.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/04-input.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/04-residuals.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/04-refined_output.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/05-input.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/05-residuals.pth (deflated 35%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/05-refined_output.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/06-input.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/06-residuals.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/06-refined_output.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/07-input.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/07-residuals.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/07-refined_output.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/08-input.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/08-residuals.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/08-refined_output.pth (deflated 34%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/09-input.pth (deflated 32%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/09-residuals.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/09-refined_output.pth (deflated 33%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/test.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/test.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-0-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-0-input.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-0-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-0-refined_output.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-1-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-1-input.png (deflated 5%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-1-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-1-refined_output.png (deflated 5%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-2-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-2-input.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-2-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-2-refined_output.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-3-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-3-input.png (deflated 5%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-3-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-3-refined_output.png (deflated 5%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-4-input.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-4-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-4-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-4-refined_output.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-5-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-5-input.png (deflated 5%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-5-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-6-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-5-refined_output.png (deflated 5%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-6-input.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-6-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-6-refined_output.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-7-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-7-input.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-7-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-7-refined_output.png (deflated 5%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-8-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-8-input.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-8-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-8-refined_output.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-9-input.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-9-input.png (deflated 4%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-9-refined_output.xml (deflated 85%)
#   adding: content/gdrive/MyDrive/Developer/coarse-to-fine-shapes/visuals/point-transformer/2024-01-30_23-46-44/pt-9-refined_output.png (deflated 4%)
